# %% [markdown]
# ![emp.PNG](attachment:emp.PNG)

# %% [markdown]
# ![ba.PNG](attachment:ba.PNG)

# %% [markdown]
# ![ov.PNG](attachment:ov.PNG)

# %% [markdown]
# ![ov.PNG](attachment:ov.PNG)

# %% [markdown]
# ![da.PNG](attachment:da.PNG)

# %% [markdown]
# ![em.PNG](attachment:em.PNG)

# %% [markdown]
# ![obs.PNG](attachment:obs.PNG)

# %% [markdown]
# ![ob.PNG](attachment:ob.PNG)

# %% [markdown]
# ![re.PNG](attachment:re.PNG)

# %% [markdown]
# ![re.PNG](attachment:re.PNG)
